# %%
import json
# /home/tom/Open-Sora-dev/tools/scoring/MA-LMM/lavis/output/camera_motion_cls/blip2_vicuna_instruct_vicuna7b/2024-10-20_15h40m07s/b12_e100_lr5e-05_wd0.05_q32_f20_fb20/result/beam5/val_epoch7.json

epoch = 5

with open(f'/home/tom/Open-Sora-dev/tools/scoring/MA-LMM/lavis/output/camera_motion_cls/blip2_vicuna_instruct_vicuna7b/2024-10-20_15h40m07s/b12_e100_lr5e-05_wd0.05_q32_f20_fb20/result/beam5/val_epoch{epoch}.json', 'r') as f:
    data = json.load(f)

data
# Out:
# [{'caption': ['zoom out', 'zoom in', 'tilt right', 'tilt left', 'move left'],
#   'image_id': 0},
#  {'caption': ['zoom out', 'zoom in', 'tilt right', 'tilt left', 'move left'],
#   'image_id': 6},
#  {'caption': ['zoom in', 'zoom out', 'tilt right', 'tilt left', 'move left'],
#   'image_id': 12},
#  {'caption': ['zoom out', 'zoom in', 'tilt right', 'tilt left', 'move left'],
#   'image_id': 18},
#  {'caption': ['zoom out', 'zoom in', 'tilt right', 'tilt left', 'move left'],
#   'image_id': 24},
#  {'caption': ['zoom out', 'zoom in', 'tilt right', 'tilt left', 'move left'],
#   'image_id': 30},
#  {'caption': ['zoom out', 'zoom in', 'tilt left', 'tilt right', 'move left'],
#   'image_id': 36},
#  {'caption': ['zoom out', 'zoom in', 'tilt right', 'tilt left', 'move left'],
#   'image_id': 42},
#  {'caption': ['zoom in', 'zoom out', 'tilt left', 'tilt right', 'move left'],
#   'image_id': 48},
#  {'caption': ['zoom in, zoom out, tilt left, tilt right, move left, move right,',
# ...

# %%
data
# Out:
# [{'caption': ['zoom out', 'zoom in', 'tilt left', 'tilt right', 'move up'],
#   'image_id': 0},
#  {'caption': ['zoom out', 'zoom in', 'move up', 'move left', 'move down'],
#   'image_id': 6},
#  {'caption': ['zoom out', 'zoom in', 'move up', 'move down', 'move left'],
#   'image_id': 12},
#  {'caption': ['zoom out', 'zoom in', 'tilt left', 'tilt right', 'move up'],
#   'image_id': 18},
#  {'caption': ['zoom out', 'zoom in', 'tilt left', 'tilt right', 'move up'],
#   'image_id': 24},
#  {'caption': ['zoom out', 'zoom in', 'tilt left', 'tilt right', 'move up'],
#   'image_id': 30},
#  {'caption': ['zoom out', 'zoom in', 'move up', 'tilt left', 'move down'],
#   'image_id': 36},
#  {'caption': ['zoom out', 'zoom in', 'tilt left', 'move up', 'tilt right'],
#   'image_id': 42},
#  {'caption': ['zoom out', 'zoom in', 'tilt right', 'tilt left', 'move up'],
#   'image_id': 48},
#  {'caption': ['zoom out', 'zoom in', 'move up', 'move left', 'move down'],
#   'image_id': 54},
# ...
